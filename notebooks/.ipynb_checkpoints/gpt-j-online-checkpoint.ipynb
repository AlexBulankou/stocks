# %%
# !pip install "ray==2.6.1"
# !pip install "ray[serve]" requests diffusers transformers fastapi==0.96
# Out:
# Collecting ray==2.6.1
#   Downloading ray-2.6.1-cp310-cp310-manylinux2014_x86_64.whl (56.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 MB 15.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (8.1.3)
# Collecting filelock (from ray==2.6.1)
#   Using cached filelock-3.12.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (4.17.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (1.0.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (23.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (4.21.12)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (6.0)
# Collecting aiosignal (from ray==2.6.1)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist (from ray==2.6.1)
#   Using cached frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (2.31.0)
# Requirement already satisfied: grpcio>=1.42.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (1.51.1)
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (1.24.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.6.1) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.6.1) (0.19.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.6.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.6.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.6.1) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.6.1) (2023.5.7)
# Installing collected packages: frozenlist, filelock, aiosignal, ray
# Successfully installed aiosignal-1.3.1 filelock-3.12.4 frozenlist-1.4.0 ray-2.6.1
# Requirement already satisfied: ray[serve] in /opt/conda/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.31.0)
# Collecting diffusers
#   Downloading diffusers-0.21.4-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 20.6 MB/s eta 0:00:0000:010:01
# Collecting transformers
#   Using cached transformers-4.34.0-py3-none-any.whl (7.7 MB)
# Collecting fastapi==0.96
#   Downloading fastapi-0.96.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 13.7 MB/s eta 0:00:00
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 (from fastapi==0.96)
#   Using cached pydantic-1.10.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi==0.96)
#   Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (8.1.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (3.12.4)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (4.17.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.0.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (23.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (4.21.12)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (6.0)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.51.1)
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.24.3)
# Collecting virtualenv<20.21.1,>=20.0.24 (from ray[serve])
#   Using cached virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
# Collecting py-spy>=0.2.0 (from ray[serve])
#   Using cached py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# Requirement already satisfied: aiohttp>=3.7 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (3.7.4.post0)
# Collecting colorful (from ray[serve])
#   Using cached colorful-0.5.5-py2.py3-none-any.whl (201 kB)
# Collecting aiohttp-cors (from ray[serve])
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (0.17.0)
# Collecting aiorwlock (from ray[serve])
#   Using cached aiorwlock-1.3.0-py3-none-any.whl (10.0 kB)
# Collecting gpustat>=1.0.0 (from ray[serve])
#   Using cached gpustat-1.1.1-py3-none-any.whl
# Collecting smart-open (from ray[serve])
#   Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Collecting uvicorn (from ray[serve])
#   Using cached uvicorn-0.23.2-py3-none-any.whl (59 kB)
# Collecting opencensus (from ray[serve])
#   Using cached opencensus-0.11.3-py2.py3-none-any.whl (128 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2023.5.7)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from diffusers) (9.5.0)
# Collecting huggingface-hub>=0.13.2 (from diffusers)
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.10/site-packages (from diffusers) (6.6.0)
# Collecting regex!=2019.12.17 (from diffusers)
#   Using cached regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
# Collecting safetensors>=0.3.1 (from diffusers)
#   Using cached safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Using cached tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (23.1.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (4.0.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (6.0.4)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (1.9.2)
# Requirement already satisfied: typing-extensions>=3.6.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (4.6.2)
# Collecting nvidia-ml-py>=11.450.129 (from gpustat>=1.0.0->ray[serve])
#   Using cached nvidia_ml_py-12.535.108-py3-none-any.whl (36 kB)
# Requirement already satisfied: psutil>=5.6.0 in /opt/conda/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[serve]) (5.9.5)
# Collecting blessed>=1.17.1 (from gpustat>=1.0.0->ray[serve])
#   Using cached blessed-1.20.0-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (2023.5.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi==0.96) (3.6.2)
# Collecting distlib<1,>=0.3.6 (from virtualenv<20.21.1,>=20.0.24->ray[serve])
#   Using cached distlib-0.3.7-py2.py3-none-any.whl (468 kB)
# Requirement already satisfied: platformdirs<4,>=2.4 in /opt/conda/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[serve]) (3.5.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[serve]) (0.19.3)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[serve])
#   Using cached opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus->ray[serve])
#   Using cached google_api_core-2.12.0-py3-none-any.whl (121 kB)
# Collecting h11>=0.8 (from uvicorn->ray[serve])
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi==0.96) (1.3.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/conda/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[serve]) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[serve]) (1.16.0)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve])
#   Using cached googleapis_common_protos-1.60.0-py2.py3-none-any.whl (227 kB)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (2.17.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (0.4.8)
# Installing collected packages: py-spy, opencensus-context, nvidia-ml-py, distlib, colorful, virtualenv, smart-open, safetensors, regex, pydantic, h11, googleapis-common-protos, blessed, aiorwlock, uvicorn, starlette, huggingface-hub, gpustat, tokenizers, google-api-core, fastapi, diffusers, aiohttp-cors, transformers, opencensus
# Successfully installed aiohttp-cors-0.7.0 aiorwlock-1.3.0 blessed-1.20.0 colorful-0.5.5 diffusers-0.21.4 distlib-0.3.7 fastapi-0.96.0 google-api-core-2.12.0 googleapis-common-protos-1.60.0 gpustat-1.1.1 h11-0.14.0 huggingface-hub-0.17.3 nvidia-ml-py-12.535.108 opencensus-0.11.3 opencensus-context-0.1.3 py-spy-0.3.14 pydantic-1.10.13 regex-2023.10.3 safetensors-0.4.0 smart-open-6.4.0 starlette-0.27.0 tokenizers-0.14.1 transformers-4.34.0 uvicorn-0.23.2 virtualenv-20.21.0

# %%
model_id = "EleutherAI/gpt-j-6B"
revision = "float16"  # use float16 weights to fit in 16GB GPUs

# %%
import ray

# %%
ray.init(
    address="ray://example-cluster-kuberay-head-svc:10001",
    runtime_env={
        "pip": [
            "IPython",
            "boto3==1.26",
            "botocore==1.29", 
            "datasets",
            "fastapi==0.96",
            "accelerate>=0.16.0",
            "transformers>=4.26.0",
            "numpy<1.24",  # remove when mlflow updates beyond 2.2
            "torch",
        ]
    }
)
# Out:
# ClientContext(dashboard_url='10.56.1.3:8265', python_version='3.10.8', ray_version='2.6.1', ray_commit='d68bf04883af2e430fc3a50fd544bb7c84aff2e9', protocol_version='2023-06-27', _num_clients=1, _context_to_restore=<ray.util.client._ClientContext object at 0x7e28fd6423e0>)

# %%
import pandas as pd

from ray import serve
from starlette.requests import Request


@serve.deployment(ray_actor_options={"num_gpus": 1})
class PredictDeployment:
    def __init__(self, model_id: str, revision: str = None):
        from transformers import AutoModelForCausalLM, AutoTokenizer
        import torch

        self.model = AutoModelForCausalLM.from_pretrained(
            model_id,
            revision=revision,
            torch_dtype=torch.float16,
            low_cpu_mem_usage=True,
            device_map="auto",  # automatically makes use of all GPUs available to the Actor
        )
        self.tokenizer = AutoTokenizer.from_pretrained(model_id)

    def generate(self, text: str) -> pd.DataFrame:
        input_ids = self.tokenizer(text, return_tensors="pt").input_ids.to(
            self.model.device
        )

        gen_tokens = self.model.generate(
            input_ids,
            do_sample=True,
            temperature=0.9,
            max_length=100,
        )
        return pd.DataFrame(
            self.tokenizer.batch_decode(gen_tokens), columns=["responses"]
        )

    async def __call__(self, http_request: Request) -> str:
        json_request: str = await http_request.json()
        prompts = []
        for prompt in json_request:
            text = prompt["text"]
            if isinstance(text, list):
                prompts.extend(text)
            else:
                prompts.append(text)
        return self.generate(prompts)

# %%
deployment = PredictDeployment.bind(model_id=model_id, revision=revision)
serve.run(deployment, host="0.0.0.0")
# Out:
# (HTTPProxyActor pid=5799) INFO:     Started server process [5799]
# (ServeController pid=5772) INFO 2023-10-08 21:37:47,437 controller 5772 deployment_state.py:1308 - Deploying new version of deployment default_PredictDeployment.
# (ServeController pid=5772) INFO 2023-10-08 21:37:47,540 controller 5772 deployment_state.py:1571 - Adding 1 replica to deployment default_PredictDeployment.
# Downloading (…)/float16/config.json: 100%|██████████| 836/836 [00:00<00:00, 6.78MB/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/12.1G [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 10.5M/12.1G [00:00<02:06, 95.7MB/s]
# Downloading pytorch_model.bin:   0%|          | 31.5M/12.1G [00:00<01:19, 151MB/s]
# Downloading pytorch_model.bin:   1%|          | 62.9M/12.1G [00:00<01:05, 183MB/s]
# Downloading pytorch_model.bin:   1%|          | 94.4M/12.1G [00:00<01:01, 196MB/s]
# Downloading pytorch_model.bin:   1%|          | 126M/12.1G [00:00<00:58, 203MB/s]
# Downloading pytorch_model.bin:   1%|▏         | 157M/12.1G [00:00<00:58, 205MB/s]
# Downloading pytorch_model.bin:   1%|▏         | 178M/12.1G [00:00<00:57, 206MB/s]
# Downloading pytorch_model.bin:   2%|▏         | 210M/12.1G [00:01<00:57, 208MB/s]
# Downloading pytorch_model.bin:   2%|▏         | 241M/12.1G [00:01<00:56, 209MB/s]
# Downloading pytorch_model.bin:   2%|▏         | 262M/12.1G [00:01<00:57, 207MB/s]
# Downloading pytorch_model.bin:   2%|▏         | 283M/12.1G [00:01<00:57, 207MB/s]
# Downloading pytorch_model.bin:   3%|▎         | 315M/12.1G [00:01<00:56, 208MB/s]
# Downloading pytorch_model.bin:   3%|▎         | 346M/12.1G [00:01<00:56, 209MB/s]
# Downloading pytorch_model.bin:   3%|▎         | 377M/12.1G [00:01<00:55, 210MB/s]
# Downloading pytorch_model.bin:   3%|▎         | 409M/12.1G [00:02<00:55, 211MB/s]
# Downloading pytorch_model.bin:   4%|▎         | 440M/12.1G [00:02<00:55, 211MB/s]
# Downloading pytorch_model.bin:   4%|▍         | 472M/12.1G [00:02<00:55, 211MB/s]
# Downloading pytorch_model.bin:   4%|▍         | 503M/12.1G [00:02<00:54, 211MB/s]
# Downloading pytorch_model.bin:   4%|▍         | 535M/12.1G [00:02<00:55, 210MB/s]
# Downloading pytorch_model.bin:   5%|▍         | 566M/12.1G [00:02<00:54, 211MB/s]
# Downloading pytorch_model.bin:   5%|▍         | 598M/12.1G [00:02<00:54, 211MB/s]
# Downloading pytorch_model.bin:   5%|▌         | 629M/12.1G [00:03<00:54, 210MB/s]
# Downloading pytorch_model.bin:   5%|▌         | 661M/12.1G [00:03<00:54, 210MB/s]
# Downloading pytorch_model.bin:   6%|▌         | 682M/12.1G [00:03<00:54, 209MB/s]
# Downloading pytorch_model.bin:   6%|▌         | 703M/12.1G [00:03<00:54, 207MB/s]
# Downloading pytorch_model.bin:   6%|▌         | 724M/12.1G [00:03<00:54, 208MB/s]
# Downloading pytorch_model.bin:   6%|▌         | 744M/12.1G [00:03<00:54, 207MB/s]
# Downloading pytorch_model.bin:   6%|▋         | 765M/12.1G [00:03<00:54, 208MB/s]
# Downloading pytorch_model.bin:   6%|▋         | 786M/12.1G [00:03<00:54, 207MB/s]
# Downloading pytorch_model.bin:   7%|▋         | 818M/12.1G [00:03<00:54, 208MB/s]
# Downloading pytorch_model.bin:   7%|▋         | 839M/12.1G [00:04<00:53, 209MB/s]
# Downloading pytorch_model.bin:   7%|▋         | 870M/12.1G [00:04<00:53, 208MB/s]
# Downloading pytorch_model.bin:   7%|▋         | 891M/12.1G [00:04<00:54, 207MB/s]
# Downloading pytorch_model.bin:   8%|▊         | 923M/12.1G [00:04<00:53, 209MB/s]
# Downloading pytorch_model.bin:   8%|▊         | 944M/12.1G [00:04<00:53, 208MB/s]
# Downloading pytorch_model.bin:   8%|▊         | 965M/12.1G [00:04<00:53, 207MB/s]
# Downloading pytorch_model.bin:   8%|▊         | 996M/12.1G [00:04<00:53, 209MB/s]
# Downloading pytorch_model.bin:   8%|▊         | 1.03G/12.1G [00:04<00:52, 210MB/s]
# Downloading pytorch_model.bin:   9%|▊         | 1.06G/12.1G [00:05<00:52, 209MB/s]
# Downloading pytorch_model.bin:   9%|▉         | 1.08G/12.1G [00:05<00:53, 207MB/s]
# Downloading pytorch_model.bin:   9%|▉         | 1.10G/12.1G [00:05<00:53, 206MB/s]
# Downloading pytorch_model.bin:   9%|▉         | 1.12G/12.1G [00:05<00:53, 206MB/s]
# Downloading pytorch_model.bin:   9%|▉         | 1.14G/12.1G [00:05<00:53, 206MB/s]
# Downloading pytorch_model.bin:  10%|▉         | 1.17G/12.1G [00:05<00:52, 208MB/s]
# Downloading pytorch_model.bin:  10%|▉         | 1.20G/12.1G [00:05<00:52, 209MB/s]
# Downloading pytorch_model.bin:  10%|█         | 1.22G/12.1G [00:05<00:52, 209MB/s]
# Downloading pytorch_model.bin:  10%|█         | 1.25G/12.1G [00:06<00:51, 210MB/s]
# Downloading pytorch_model.bin:  11%|█         | 1.28G/12.1G [00:06<00:51, 209MB/s]
# Downloading pytorch_model.bin:  11%|█         | 1.31G/12.1G [00:06<00:51, 208MB/s]
# Downloading pytorch_model.bin:  11%|█         | 1.33G/12.1G [00:06<00:51, 208MB/s]
# Downloading pytorch_model.bin:  11%|█▏        | 1.36G/12.1G [00:06<00:51, 210MB/s]
# Downloading pytorch_model.bin:  11%|█▏        | 1.38G/12.1G [00:06<00:51, 208MB/s]
# Downloading pytorch_model.bin:  12%|█▏        | 1.41G/12.1G [00:06<00:51, 208MB/s]
# Downloading pytorch_model.bin:  12%|█▏        | 1.43G/12.1G [00:06<00:51, 208MB/s]
# Downloading pytorch_model.bin:  12%|█▏        | 1.45G/12.1G [00:06<00:51, 207MB/s]
# Downloading pytorch_model.bin:  12%|█▏        | 1.48G/12.1G [00:07<00:50, 209MB/s]
# Downloading pytorch_model.bin:  12%|█▏        | 1.50G/12.1G [00:07<00:50, 208MB/s]
# Downloading pytorch_model.bin:  13%|█▎        | 1.52G/12.1G [00:07<00:51, 207MB/s]
# Downloading pytorch_model.bin:  13%|█▎        | 1.55G/12.1G [00:07<00:50, 208MB/s]
# Downloading pytorch_model.bin:  13%|█▎        | 1.58G/12.1G [00:07<00:50, 208MB/s]
# Downloading pytorch_model.bin:  13%|█▎        | 1.60G/12.1G [00:07<00:50, 208MB/s]
# Downloading pytorch_model.bin:  14%|█▎        | 1.64G/12.1G [00:07<00:50, 209MB/s]
# Downloading pytorch_model.bin:  14%|█▎        | 1.66G/12.1G [00:07<00:50, 207MB/s]
# Downloading pytorch_model.bin:  14%|█▍        | 1.69G/12.1G [00:08<00:49, 208MB/s]
# Downloading pytorch_model.bin:  14%|█▍        | 1.72G/12.1G [00:08<00:49, 210MB/s]
# Downloading pytorch_model.bin:  14%|█▍        | 1.74G/12.1G [00:08<00:49, 208MB/s]
# Downloading pytorch_model.bin:  15%|█▍        | 1.77G/12.1G [00:08<00:49, 208MB/s]
# Downloading pytorch_model.bin:  15%|█▍        | 1.79G/12.1G [00:08<00:49, 208MB/s]
# Downloading pytorch_model.bin:  15%|█▍        | 1.81G/12.1G [00:08<00:49, 208MB/s]
# Downloading pytorch_model.bin:  15%|█▌        | 1.84G/12.1G [00:08<00:49, 208MB/s]
# Downloading pytorch_model.bin:  15%|█▌        | 1.87G/12.1G [00:09<00:49, 209MB/s]
# Downloading pytorch_model.bin:  16%|█▌        | 1.90G/12.1G [00:09<00:48, 209MB/s]
# Downloading pytorch_model.bin:  16%|█▌        | 1.92G/12.1G [00:09<00:49, 208MB/s]
# Downloading pytorch_model.bin:  16%|█▌        | 1.94G/12.1G [00:09<00:49, 207MB/s]
# Downloading pytorch_model.bin:  16%|█▋        | 1.97G/12.1G [00:09<00:48, 208MB/s]
# Downloading pytorch_model.bin:  17%|█▋        | 2.00G/12.1G [00:09<00:48, 210MB/s]
# Downloading pytorch_model.bin:  17%|█▋        | 2.03G/12.1G [00:09<00:47, 212MB/s]
# Downloading pytorch_model.bin:  17%|█▋        | 2.07G/12.1G [00:09<00:47, 212MB/s]
# Downloading pytorch_model.bin:  17%|█▋        | 2.10G/12.1G [00:10<00:47, 211MB/s]
# Downloading pytorch_model.bin:  18%|█▊        | 2.13G/12.1G [00:10<00:47, 210MB/s]
# Downloading pytorch_model.bin:  18%|█▊        | 2.16G/12.1G [00:10<00:47, 209MB/s]
# Downloading pytorch_model.bin:  18%|█▊        | 2.18G/12.1G [00:10<00:47, 207MB/s]
# Downloading pytorch_model.bin:  18%|█▊        | 2.21G/12.1G [00:10<00:47, 208MB/s]
# Downloading pytorch_model.bin:  18%|█▊        | 2.23G/12.1G [00:10<00:47, 207MB/s]
# Downloading pytorch_model.bin:  19%|█▊        | 2.25G/12.1G [00:10<00:47, 207MB/s]
# Downloading pytorch_model.bin:  19%|█▉        | 2.28G/12.1G [00:10<00:47, 207MB/s]
# Downloading pytorch_model.bin:  19%|█▉        | 2.31G/12.1G [00:11<00:46, 209MB/s]
# Downloading pytorch_model.bin:  19%|█▉        | 2.34G/12.1G [00:11<00:46, 209MB/s]
# Downloading pytorch_model.bin:  19%|█▉        | 2.36G/12.1G [00:11<00:46, 208MB/s]
# Downloading pytorch_model.bin:  20%|█▉        | 2.38G/12.1G [00:11<00:46, 208MB/s]
# Downloading pytorch_model.bin:  20%|█▉        | 2.41G/12.1G [00:11<00:46, 209MB/s]
# Downloading pytorch_model.bin:  20%|██        | 2.43G/12.1G [00:11<00:46, 208MB/s]
# Downloading pytorch_model.bin:  20%|██        | 2.46G/12.1G [00:11<00:46, 209MB/s]
# Downloading pytorch_model.bin:  21%|██        | 2.49G/12.1G [00:11<00:46, 208MB/s]
# Downloading pytorch_model.bin:  21%|██        | 2.52G/12.1G [00:12<00:45, 209MB/s]
# Downloading pytorch_model.bin:  21%|██        | 2.55G/12.1G [00:12<00:45, 210MB/s]
# Downloading pytorch_model.bin:  21%|██        | 2.57G/12.1G [00:12<00:45, 208MB/s]
# Downloading pytorch_model.bin:  21%|██▏       | 2.60G/12.1G [00:12<00:45, 208MB/s]
# Downloading pytorch_model.bin:  22%|██▏       | 2.62G/12.1G [00:12<00:45, 209MB/s]
# Downloading pytorch_model.bin:  22%|██▏       | 2.64G/12.1G [00:12<00:45, 207MB/s]
# Downloading pytorch_model.bin:  22%|██▏       | 2.66G/12.1G [00:12<00:45, 208MB/s]
# Downloading pytorch_model.bin:  22%|██▏       | 2.68G/12.1G [00:12<00:45, 208MB/s]
# Downloading pytorch_model.bin:  22%|██▏       | 2.71G/12.1G [00:13<00:45, 208MB/s]
# Downloading pytorch_model.bin:  23%|██▎       | 2.73G/12.1G [00:13<00:49, 191MB/s]
# Downloading pytorch_model.bin:  23%|██▎       | 2.75G/12.1G [00:13<00:47, 196MB/s]
# Downloading pytorch_model.bin:  23%|██▎       | 2.78G/12.1G [00:13<00:46, 202MB/s]
# Downloading pytorch_model.bin:  30%|███       | 3.68G/12.1G [00:18<00:49, 171MB/s]
# Downloading pytorch_model.bin:  31%|███       | 3.70G/12.1G [00:18<00:46, 180MB/s]
# Downloading pytorch_model.bin:  31%|███       | 3.72G/12.1G [00:18<00:44, 187MB/s]
# Downloading pytorch_model.bin:  31%|███       | 3.74G/12.1G [00:18<00:43, 193MB/s]
# Downloading pytorch_model.bin:  31%|███       | 3.77G/12.1G [00:19<00:41, 200MB/s]
# Downloading pytorch_model.bin:  31%|███▏      | 3.80G/12.1G [00:19<00:41, 202MB/s]
# Downloading pytorch_model.bin:  32%|███▏      | 3.82G/12.1G [00:19<00:40, 204MB/s]
# Downloading pytorch_model.bin:  32%|███▏      | 3.84G/12.1G [00:19<00:40, 205MB/s]
# Downloading pytorch_model.bin:  32%|███▏      | 3.86G/12.1G [00:19<00:40, 206MB/s]
# Downloading pytorch_model.bin:  32%|███▏      | 3.89G/12.1G [00:19<00:39, 208MB/s]
# Downloading pytorch_model.bin:  32%|███▏      | 3.92G/12.1G [00:19<00:38, 210MB/s]
# Downloading pytorch_model.bin:  33%|███▎      | 3.95G/12.1G [00:19<00:38, 210MB/s]
# Downloading pytorch_model.bin:  33%|███▎      | 3.98G/12.1G [00:20<00:38, 210MB/s]
# Downloading pytorch_model.bin:  33%|███▎      | 4.02G/12.1G [00:20<00:40, 199MB/s]
# Downloading pytorch_model.bin:  33%|███▎      | 4.04G/12.1G [00:20<01:09, 116MB/s]
# Downloading pytorch_model.bin:  34%|███▎      | 4.07G/12.1G [00:20<00:59, 136MB/s]
# Downloading pytorch_model.bin:  34%|███▍      | 4.10G/12.1G [00:21<00:52, 154MB/s]
# Downloading pytorch_model.bin:  34%|███▍      | 4.12G/12.1G [00:21<00:50, 158MB/s]
# Downloading pytorch_model.bin:  34%|███▍      | 4.14G/12.1G [00:21<00:54, 145MB/s]
# Downloading pytorch_model.bin:  34%|███▍      | 4.16G/12.1G [00:21<00:58, 135MB/s]
# Downloading pytorch_model.bin:  35%|███▍      | 4.18G/12.1G [00:21<01:00, 131MB/s]
# Downloading pytorch_model.bin:  35%|███▍      | 4.20G/12.1G [00:21<01:02, 126MB/s]
# Downloading pytorch_model.bin:  35%|███▍      | 4.23G/12.1G [00:22<01:02, 126MB/s]
# Downloading pytorch_model.bin:  35%|███▌      | 4.25G/12.1G [00:22<01:03, 124MB/s]
# Downloading pytorch_model.bin:  35%|███▌      | 4.27G/12.1G [00:22<01:04, 122MB/s]
# Downloading pytorch_model.bin:  35%|███▌      | 4.29G/12.1G [00:22<01:04, 121MB/s]
# Downloading pytorch_model.bin:  36%|███▌      | 4.31G/12.1G [00:22<01:04, 120MB/s]
# Downloading pytorch_model.bin:  36%|███▌      | 4.33G/12.1G [00:22<01:04, 121MB/s]
# Downloading pytorch_model.bin:  36%|███▌      | 4.35G/12.1G [00:23<01:03, 121MB/s]
# Downloading pytorch_model.bin:  36%|███▌      | 4.37G/12.1G [00:23<01:04, 121MB/s]
# Downloading pytorch_model.bin:  36%|███▋      | 4.39G/12.1G [00:23<01:18, 98.0MB/s]
# Downloading pytorch_model.bin:  37%|███▋      | 4.42G/12.1G [00:23<01:01, 124MB/s]
# Downloading pytorch_model.bin:  37%|███▋      | 4.45G/12.1G [00:23<00:57, 133MB/s]
# Downloading pytorch_model.bin:  37%|███▋      | 4.47G/12.1G [00:24<00:59, 128MB/s]
# Downloading pytorch_model.bin:  37%|███▋      | 4.49G/12.1G [00:24<01:00, 126MB/s]
# Downloading pytorch_model.bin:  37%|███▋      | 4.51G/12.1G [00:24<01:01, 124MB/s]
# Downloading pytorch_model.bin:  37%|███▋      | 4.53G/12.1G [00:24<01:01, 123MB/s]
# Downloading pytorch_model.bin:  38%|███▊      | 4.55G/12.1G [00:24<01:02, 121MB/s]
# Downloading pytorch_model.bin:  38%|███▊      | 4.57G/12.1G [00:24<01:01, 122MB/s]
# Downloading pytorch_model.bin:  38%|███▊      | 4.59G/12.1G [00:25<01:01, 122MB/s]
# (ServeController pid=5772) WARNING 2023-10-08 21:38:17,635 controller 5772 deployment_state.py:1902 - Deployment default_PredictDeployment has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# Downloading pytorch_model.bin:  38%|███▊      | 4.61G/12.1G [00:25<01:01, 122MB/s]
# Downloading pytorch_model.bin:  38%|███▊      | 4.63G/12.1G [00:25<01:23, 90.0MB/s]
# Downloading pytorch_model.bin:  38%|███▊      | 4.66G/12.1G [00:25<01:09, 108MB/s]
# Downloading pytorch_model.bin:  39%|███▊      | 4.68G/12.1G [00:25<00:58, 126MB/s]
# Downloading pytorch_model.bin:  39%|███▉      | 4.70G/12.1G [00:25<00:51, 143MB/s]
# Downloading pytorch_model.bin:  39%|███▉      | 4.74G/12.1G [00:26<00:55, 132MB/s]
# Downloading pytorch_model.bin:  39%|███▉      | 4.76G/12.1G [00:26<00:57, 128MB/s]
# Downloading pytorch_model.bin:  39%|███▉      | 4.78G/12.1G [00:26<00:59, 124MB/s]
# Downloading pytorch_model.bin:  40%|███▉      | 4.80G/12.1G [00:26<01:09, 105MB/s]
# Downloading pytorch_model.bin:  40%|███▉      | 4.83G/12.1G [00:27<00:57, 127MB/s]
# Downloading pytorch_model.bin:  40%|████      | 4.85G/12.1G [00:27<00:58, 125MB/s]
# Downloading pytorch_model.bin:  40%|████      | 4.88G/12.1G [00:27<00:59, 121MB/s]
# Downloading pytorch_model.bin:  40%|████      | 4.90G/12.1G [00:27<01:08, 106MB/s]
# Downloading pytorch_model.bin:  41%|████      | 4.92G/12.1G [00:27<00:58, 123MB/s]
# Downloading pytorch_model.bin:  41%|████      | 4.94G/12.1G [00:27<00:57, 125MB/s]
# Downloading pytorch_model.bin:  41%|████      | 4.96G/12.1G [00:28<00:57, 124MB/s]
# Downloading pytorch_model.bin:  41%|████      | 4.98G/12.1G [00:28<01:23, 85.2MB/s]
# Downloading pytorch_model.bin:  41%|████▏     | 5.00G/12.1G [00:28<01:09, 103MB/s]
# Downloading pytorch_model.bin:  41%|████▏     | 5.02G/12.1G [00:28<00:58, 121MB/s]
# Downloading pytorch_model.bin:  42%|████▏     | 5.04G/12.1G [00:28<00:51, 138MB/s]
# Downloading pytorch_model.bin:  42%|████▏     | 5.06G/12.1G [00:28<00:48, 144MB/s]
# Downloading pytorch_model.bin:  42%|████▏     | 5.09G/12.1G [00:29<00:54, 129MB/s]
# Downloading pytorch_model.bin:  42%|████▏     | 5.11G/12.1G [00:29<00:53, 131MB/s]
# Downloading pytorch_model.bin:  42%|████▏     | 5.13G/12.1G [00:29<00:55, 126MB/s]
# Downloading pytorch_model.bin:  49%|████▉     | 5.91G/12.1G [00:36<00:50, 123MB/s]
# Downloading pytorch_model.bin:  49%|████▉     | 5.95G/12.1G [00:36<00:43, 143MB/s]
# Downloading pytorch_model.bin:  49%|████▉     | 5.97G/12.1G [00:36<00:45, 136MB/s]
# Downloading pytorch_model.bin:  49%|████▉     | 5.99G/12.1G [00:36<00:47, 129MB/s]
# Downloading pytorch_model.bin:  50%|████▉     | 6.01G/12.1G [00:36<00:48, 125MB/s]
# Downloading pytorch_model.bin:  50%|████▉     | 6.03G/12.1G [00:37<00:49, 122MB/s]
# Downloading pytorch_model.bin:  50%|████▉     | 6.05G/12.1G [00:37<00:54, 110MB/s]
# Downloading pytorch_model.bin:  50%|█████     | 6.07G/12.1G [00:37<00:49, 121MB/s]
# Downloading pytorch_model.bin:  50%|█████     | 6.09G/12.1G [00:37<00:49, 121MB/s]
# Downloading pytorch_model.bin:  50%|█████     | 6.11G/12.1G [00:37<00:50, 119MB/s]
# Downloading pytorch_model.bin:  51%|█████     | 6.13G/12.1G [00:38<00:50, 118MB/s]
# Downloading pytorch_model.bin:  51%|█████     | 6.16G/12.1G [00:38<00:50, 118MB/s]
# Downloading pytorch_model.bin:  51%|█████     | 6.18G/12.1G [00:38<01:07, 87.9MB/s]
# Downloading pytorch_model.bin:  51%|█████▏    | 6.21G/12.1G [00:38<00:51, 114MB/s]
# Downloading pytorch_model.bin:  51%|█████▏    | 6.23G/12.1G [00:38<00:45, 130MB/s]
# Downloading pytorch_model.bin:  52%|█████▏    | 6.25G/12.1G [00:38<00:42, 139MB/s]
# Downloading pytorch_model.bin:  52%|█████▏    | 6.27G/12.1G [00:39<00:44, 131MB/s]
# Downloading pytorch_model.bin:  52%|█████▏    | 6.29G/12.1G [00:39<00:45, 128MB/s]
# Downloading pytorch_model.bin:  52%|█████▏    | 6.31G/12.1G [00:39<00:46, 125MB/s]
# Downloading pytorch_model.bin:  52%|█████▏    | 6.35G/12.1G [00:39<00:47, 120MB/s]
# Downloading pytorch_model.bin:  53%|█████▎    | 6.38G/12.1G [00:40<00:48, 119MB/s]
# Downloading pytorch_model.bin:  53%|█████▎    | 6.40G/12.1G [00:40<00:48, 118MB/s]
# Downloading pytorch_model.bin:  53%|█████▎    | 6.42G/12.1G [00:40<01:07, 84.4MB/s]
# Downloading pytorch_model.bin:  53%|█████▎    | 6.44G/12.1G [00:40<00:55, 103MB/s]
# Downloading pytorch_model.bin:  53%|█████▎    | 6.46G/12.1G [00:40<00:46, 121MB/s]
# Downloading pytorch_model.bin:  54%|█████▎    | 6.48G/12.1G [00:40<00:40, 138MB/s]
# Downloading pytorch_model.bin:  54%|█████▎    | 6.50G/12.1G [00:41<00:39, 143MB/s]
# Downloading pytorch_model.bin:  54%|█████▍    | 6.52G/12.1G [00:41<00:41, 133MB/s]
# Downloading pytorch_model.bin:  54%|█████▍    | 6.54G/12.1G [00:41<00:43, 127MB/s]
# Downloading pytorch_model.bin:  54%|█████▍    | 6.56G/12.1G [00:41<00:44, 125MB/s]
# Downloading pytorch_model.bin:  54%|█████▍    | 6.59G/12.1G [00:41<00:45, 122MB/s]
# Downloading pytorch_model.bin:  55%|█████▍    | 6.61G/12.1G [00:41<00:45, 120MB/s]
# Downloading pytorch_model.bin:  55%|█████▍    | 6.63G/12.1G [00:42<00:46, 119MB/s]
# Downloading pytorch_model.bin:  55%|█████▍    | 6.65G/12.1G [00:42<00:46, 118MB/s]
# Downloading pytorch_model.bin:  55%|█████▌    | 6.67G/12.1G [00:42<00:46, 117MB/s]
# Downloading pytorch_model.bin:  55%|█████▌    | 6.69G/12.1G [00:42<00:45, 118MB/s]
# Downloading pytorch_model.bin:  55%|█████▌    | 6.71G/12.1G [00:42<00:48, 112MB/s]
# Downloading pytorch_model.bin:  56%|█████▌    | 6.73G/12.1G [00:43<00:45, 118MB/s]
# Downloading pytorch_model.bin:  56%|█████▌    | 6.75G/12.1G [00:43<01:03, 83.8MB/s]
# Downloading pytorch_model.bin:  56%|█████▌    | 6.78G/12.1G [00:43<00:48, 109MB/s]
# Downloading pytorch_model.bin:  56%|█████▋    | 6.82G/12.1G [00:43<00:39, 132MB/s]
# Downloading pytorch_model.bin:  56%|█████▋    | 6.84G/12.1G [00:43<00:38, 136MB/s]
# Downloading pytorch_model.bin:  57%|█████▋    | 6.86G/12.1G [00:44<00:41, 128MB/s]
# Downloading pytorch_model.bin:  57%|█████▋    | 6.88G/12.1G [00:44<00:40, 128MB/s]
# Downloading pytorch_model.bin:  57%|█████▋    | 6.90G/12.1G [00:44<00:42, 124MB/s]
# Downloading pytorch_model.bin:  57%|█████▋    | 6.94G/12.1G [00:44<00:43, 120MB/s]
# Downloading pytorch_model.bin:  58%|█████▊    | 6.96G/12.1G [00:45<00:54, 94.6MB/s]
# Downloading pytorch_model.bin:  58%|█████▊    | 6.98G/12.1G [00:45<00:45, 113MB/s]
# Downloading pytorch_model.bin:  58%|█████▊    | 7.00G/12.1G [00:45<00:39, 130MB/s]
# Downloading pytorch_model.bin:  58%|█████▊    | 7.03G/12.1G [00:45<00:42, 120MB/s]
# Downloading pytorch_model.bin:  58%|█████▊    | 7.05G/12.1G [00:45<00:38, 130MB/s]
# Downloading pytorch_model.bin:  58%|█████▊    | 7.07G/12.1G [00:46<00:57, 87.9MB/s]
# Downloading pytorch_model.bin:  59%|█████▊    | 7.10G/12.1G [00:46<00:43, 114MB/s]
# Downloading pytorch_model.bin:  59%|█████▉    | 7.13G/12.1G [00:46<00:36, 137MB/s]
# Downloading pytorch_model.bin:  59%|█████▉    | 7.15G/12.1G [00:46<00:37, 133MB/s]
# Downloading pytorch_model.bin:  59%|█████▉    | 7.17G/12.1G [00:46<00:41, 119MB/s]
# Downloading pytorch_model.bin:  59%|█████▉    | 7.19G/12.1G [00:46<00:38, 129MB/s]
# Downloading pytorch_model.bin:  60%|█████▉    | 7.21G/12.1G [00:47<00:38, 126MB/s]
# Downloading pytorch_model.bin:  60%|█████▉    | 7.24G/12.1G [00:47<00:39, 124MB/s]
# Downloading pytorch_model.bin:  60%|█████▉    | 7.26G/12.1G [00:47<00:41, 117MB/s]
# Downloading pytorch_model.bin:  60%|██████    | 7.28G/12.1G [00:47<00:40, 120MB/s]
# Downloading pytorch_model.bin:  60%|██████    | 7.30G/12.1G [00:47<00:40, 120MB/s]
# Downloading pytorch_model.bin:  61%|██████    | 7.34G/12.1G [00:48<00:40, 117MB/s]
# Downloading pytorch_model.bin:  61%|██████    | 7.36G/12.1G [00:48<00:40, 118MB/s]
# Downloading pytorch_model.bin:  61%|██████    | 7.38G/12.1G [00:48<00:48, 97.7MB/s]
# Downloading pytorch_model.bin:  61%|██████    | 7.40G/12.1G [00:48<00:40, 116MB/s]
# Downloading pytorch_model.bin:  61%|██████▏   | 7.42G/12.1G [00:48<00:36, 127MB/s]
# Downloading pytorch_model.bin:  61%|██████▏   | 7.44G/12.1G [00:49<00:37, 123MB/s]
# Downloading pytorch_model.bin:  62%|██████▏   | 7.47G/12.1G [00:49<00:41, 113MB/s]
# Downloading pytorch_model.bin:  62%|██████▏   | 7.49G/12.1G [00:49<00:37, 124MB/s]
# Downloading pytorch_model.bin:  62%|██████▏   | 7.51G/12.1G [00:49<00:37, 122MB/s]
# Downloading pytorch_model.bin:  62%|██████▏   | 7.53G/12.1G [00:49<00:38, 119MB/s]
# Downloading pytorch_model.bin:  62%|██████▏   | 7.55G/12.1G [00:50<00:41, 110MB/s]
# Downloading pytorch_model.bin:  63%|██████▎   | 7.57G/12.1G [00:50<00:37, 121MB/s]
# Downloading pytorch_model.bin:  63%|██████▎   | 7.59G/12.1G [00:50<00:37, 122MB/s]
# Downloading pytorch_model.bin:  63%|██████▎   | 7.61G/12.1G [00:50<00:37, 121MB/s]
# Downloading pytorch_model.bin:  63%|██████▎   | 7.63G/12.1G [00:50<00:51, 86.9MB/s]
# Downloading pytorch_model.bin:  63%|██████▎   | 7.65G/12.1G [00:51<00:42, 105MB/s]
# Downloading pytorch_model.bin:  63%|██████▎   | 7.69G/12.1G [00:51<00:33, 131MB/s]
# Downloading pytorch_model.bin:  64%|██████▎   | 7.71G/12.1G [00:51<00:32, 134MB/s]
# Downloading pytorch_model.bin:  64%|██████▍   | 7.73G/12.1G [00:51<00:33, 131MB/s]
# Downloading pytorch_model.bin:  64%|██████▍   | 7.75G/12.1G [00:51<00:34, 126MB/s]
# Downloading pytorch_model.bin:  64%|██████▍   | 7.77G/12.1G [00:51<00:34, 124MB/s]
# Downloading pytorch_model.bin:  64%|██████▍   | 7.79G/12.1G [00:52<00:35, 122MB/s]
# Downloading pytorch_model.bin:  65%|██████▍   | 7.81G/12.1G [00:52<00:37, 115MB/s]
# Downloading pytorch_model.bin:  65%|██████▍   | 7.83G/12.1G [00:52<00:35, 122MB/s]
# Downloading pytorch_model.bin:  65%|██████▍   | 7.85G/12.1G [00:52<00:35, 120MB/s]
# Downloading pytorch_model.bin:  65%|██████▌   | 7.87G/12.1G [00:52<00:35, 120MB/s]
# Downloading pytorch_model.bin:  65%|██████▌   | 7.90G/12.1G [00:52<00:35, 120MB/s]
# Downloading pytorch_model.bin:  65%|██████▌   | 7.92G/12.1G [00:53<00:37, 113MB/s]
# Downloading pytorch_model.bin:  66%|██████▌   | 7.94G/12.1G [00:53<00:34, 120MB/s]
# Downloading pytorch_model.bin:  66%|██████▌   | 7.96G/12.1G [00:53<00:49, 84.0MB/s]
# Downloading pytorch_model.bin:  66%|██████▌   | 7.98G/12.1G [00:53<00:40, 102MB/s]
# Downloading pytorch_model.bin:  66%|██████▌   | 8.00G/12.1G [00:53<00:34, 120MB/s]
# Downloading pytorch_model.bin:  66%|██████▋   | 8.02G/12.1G [00:54<00:30, 133MB/s]
# Downloading pytorch_model.bin:  66%|██████▋   | 8.04G/12.1G [00:54<00:28, 140MB/s]
# Downloading pytorch_model.bin:  67%|██████▋   | 8.06G/12.1G [00:54<00:30, 132MB/s]
# Downloading pytorch_model.bin:  67%|██████▋   | 8.11G/12.1G [00:54<00:32, 124MB/s]
# Downloading pytorch_model.bin:  67%|██████▋   | 8.13G/12.1G [00:54<00:32, 123MB/s]
# Downloading pytorch_model.bin:  67%|██████▋   | 8.15G/12.1G [00:55<00:32, 122MB/s]
# Downloading pytorch_model.bin:  67%|██████▋   | 8.17G/12.1G [00:55<00:32, 121MB/s]
# Downloading pytorch_model.bin:  68%|██████▊   | 8.19G/12.1G [00:55<00:32, 119MB/s]
# (ServeController pid=5772) WARNING 2023-10-08 21:38:47,789 controller 5772 deployment_state.py:1902 - Deployment default_PredictDeployment has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# Downloading pytorch_model.bin:  68%|██████▊   | 8.21G/12.1G [00:55<00:32, 119MB/s]
# Downloading pytorch_model.bin:  68%|██████▊   | 8.23G/12.1G [00:55<00:45, 85.1MB/s]
# Downloading pytorch_model.bin:  68%|██████▊   | 8.26G/12.1G [00:56<00:34, 111MB/s]
# Downloading pytorch_model.bin:  69%|██████▊   | 8.29G/12.1G [00:56<00:28, 134MB/s]
# Downloading pytorch_model.bin:  69%|██████▊   | 8.32G/12.1G [00:56<00:30, 125MB/s]
# Downloading pytorch_model.bin:  69%|██████▉   | 8.34G/12.1G [00:56<00:29, 127MB/s]
# Downloading pytorch_model.bin:  69%|██████▉   | 8.36G/12.1G [00:56<00:29, 126MB/s]
# Downloading pytorch_model.bin:  69%|██████▉   | 8.38G/12.1G [00:56<00:30, 124MB/s]
# Downloading pytorch_model.bin:  69%|██████▉   | 8.40G/12.1G [00:57<00:30, 121MB/s]
# Downloading pytorch_model.bin:  70%|██████▉   | 8.42G/12.1G [00:57<00:30, 120MB/s]
# Downloading pytorch_model.bin:  70%|██████▉   | 8.44G/12.1G [00:57<00:30, 121MB/s]
# Downloading pytorch_model.bin:  70%|██████▉   | 8.46G/12.1G [00:57<00:30, 119MB/s]
# Downloading pytorch_model.bin:  70%|███████   | 8.48G/12.1G [00:57<00:32, 112MB/s]
# Downloading pytorch_model.bin:  70%|███████   | 8.51G/12.1G [00:58<00:47, 76.1MB/s]
# Downloading pytorch_model.bin:  71%|███████   | 8.54G/12.1G [00:58<00:36, 96.6MB/s]
# Downloading pytorch_model.bin:  71%|███████   | 8.56G/12.1G [00:58<00:30, 117MB/s]
# Downloading pytorch_model.bin:  71%|███████   | 8.59G/12.1G [00:58<00:24, 144MB/s]
# Downloading pytorch_model.bin:  71%|███████   | 8.61G/12.1G [00:58<00:22, 157MB/s]
# Downloading pytorch_model.bin:  71%|███████▏  | 8.63G/12.1G [00:59<00:25, 138MB/s]
# Downloading pytorch_model.bin:  71%|███████▏  | 8.65G/12.1G [00:59<00:23, 144MB/s]
# Downloading pytorch_model.bin:  72%|███████▏  |
# Downloading pytorch_model.bin:  89%|████████▉ | 10.8G/12.1G [01:17<00:10, 126MB/s]
# Downloading pytorch_model.bin:  89%|████████▉ | 10.8G/12.1G [01:17<00:10, 125MB/s]
# Downloading pytorch_model.bin:  89%|████████▉ | 10.8G/12.1G [01:17<00:11, 117MB/s]
# Downloading pytorch_model.bin:  90%|████████▉ | 10.8G/12.1G [01:17<00:10, 124MB/s]
# Downloading pytorch_model.bin:  90%|████████▉ | 10.9G/12.1G [01:17<00:10, 121MB/s]
# Downloading pytorch_model.bin:  90%|████████▉ | 10.9G/12.1G [01:18<00:10, 122MB/s]
# Downloading pytorch_model.bin:  90%|█████████ | 10.9G/12.1G [01:18<00:09, 120MB/s]
# Downloading pytorch_model.bin:  90%|█████████ | 10.9G/12.1G [01:18<00:10, 109MB/s]
# Downloading pytorch_model.bin:  90%|█████████ | 10.9G/12.1G [01:18<00:09, 123MB/s]
# Downloading pytorch_model.bin:  91%|█████████ | 11.0G/12.1G [01:18<00:09, 124MB/s]
# Downloading pytorch_model.bin:  91%|█████████ | 11.0G/12.1G [01:18<00:09, 121MB/s]
# Downloading pytorch_model.bin:  91%|█████████ | 11.0G/12.1G [01:19<00:12, 87.7MB/s]
# Downloading pytorch_model.bin:  91%|█████████ | 11.0G/12.1G [01:19<00:09, 114MB/s]
# Downloading pytorch_model.bin:  91%|█████████▏| 11.1G/12.1G [01:19<00:08, 130MB/s]
# Downloading pytorch_model.bin:  92%|█████████▏| 11.1G/12.1G [01:19<00:07, 137MB/s]
# Downloading pytorch_model.bin:  92%|█████████▏| 11.1G/12.1G [01:19<00:08, 122MB/s]
# Downloading pytorch_model.bin:  92%|█████████▏| 11.1G/12.1G [01:20<00:07, 129MB/s]
# Downloading pytorch_model.bin:  92%|█████████▏| 11.1G/12.1G [01:20<00:07, 125MB/s]
# Downloading pytorch_model.bin:  92%|█████████▏| 11.2G/12.1G [01:20<00:07, 125MB/s]
# Downloading pytorch_model.bin:  92%|█████████▏| 11.2G/12.1G [01:20<00:08, 110MB/s]
# Downloading pytorch_model.bin:  93%|█████████▎| 11.2G/12.1G [01:20<00:07, 126MB/s]
# Downloading pytorch_model.bin:  93%|█████████▎| 11.2G/12.1G [01:20<00:07, 123MB/s]
# Downloading pytorch_model.bin:  93%|█████████▎| 11.3G/12.1G [01:21<00:06, 124MB/s]
# Downloading pytorch_model.bin:  93%|█████████▎| 11.3G/12.1G [01:21<00:07, 115MB/s]
# Downloading pytorch_model.bin:  93%|█████████▎| 11.3G/12.1G [01:21<00:06, 124MB/s]
# Downloading pytorch_model.bin:  93%|█████████▎| 11.3G/12.1G [01:21<00:06, 121MB/s]
# Downloading pytorch_model.bin:  94%|█████████▎| 11.3G/12.1G [01:21<00:06, 122MB/s]
# Downloading pytorch_model.bin:  94%|█████████▍| 11.4G/12.1G [01:22<00:08, 86.2MB/s]
# Downloading pytorch_model.bin:  94%|█████████▍| 11.4G/12.1G [01:22<00:06, 105MB/s]
# Downloading pytorch_model.bin:  94%|█████████▍| 11.4G/12.1G [01:22<00:05, 131MB/s]
# Downloading pytorch_model.bin:  94%|█████████▍| 11.4G/12.1G [01:22<00:04, 138MB/s]
# Downloading pytorch_model.bin:  95%|█████████▍| 11.5G/12.1G [01:22<00:05, 129MB/s]
# Downloading pytorch_model.bin:  95%|█████████▍| 11.5G/12.1G [01:22<00:04, 129MB/s]
# Downloading pytorch_model.bin:  95%|█████████▍| 11.5G/12.1G [01:23<00:04, 125MB/s]
# Downloading pytorch_model.bin:  95%|█████████▌| 11.5G/12.1G [01:23<00:04, 124MB/s]
# Downloading pytorch_model.bin:  95%|█████████▌| 11.5G/12.1G [01:23<00:04, 122MB/s]
# Downloading pytorch_model.bin:  95%|█████████▌| 11.6G/12.1G [01:23<00:04, 123MB/s]
# Downloading pytorch_model.bin:  96%|█████████▌| 11.6G/12.1G [01:23<00:04, 121MB/s]
# Downloading pytorch_model.bin:  96%|█████████▌| 11.6G/12.1G [01:24<00:04, 121MB/s]
# Downloading pytorch_model.bin:  96%|█████████▌| 11.6G/12.1G [01:24<00:04, 120MB/s]
# Downloading pytorch_model.bin:  96%|█████████▌| 11.6G/12.1G [01:24<00:05, 85.4MB/s]
# Downloading pytorch_model.bin:  96%|█████████▋| 11.7G/12.1G [01:24<00:04, 104MB/s]
# Downloading pytorch_model.bin:  96%|█████████▋| 11.7G/12.1G [01:24<00:03, 122MB/s]
# Downloading pytorch_model.bin:  97%|█████████▋| 11.7G/12.1G [01:24<00:02, 138MB/s]
# Downloading pytorch_model.bin:  97%|█████████▋| 11.7G/12.1G [01:25<00:02, 138MB/s]
# Downloading pytorch_model.bin:  97%|█████████▋| 11.7G/12.1G [01:25<00:02, 132MB/s]
# Downloading pytorch_model.bin:  97%|█████████▋| 11.8G/12.1G [01:25<00:02, 127MB/s]
# (ServeController pid=5772) WARNING 2023-10-08 21:39:17,856 controller 5772 deployment_state.py:1902 - Deployment default_PredictDeployment has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# Downloading pytorch_model.bin:  97%|█████████▋| 11.8G/12.1G [01:25<00:02, 126MB/s]
# Downloading pytorch_model.bin:  98%|█████████▊| 11.8G/12.1G [01:25<00:02, 123MB/s]
# Downloading pytorch_model.bin:  98%|█████████▊| 11.8G/12.1G [01:25<00:02, 122MB/s]
# Downloading pytorch_model.bin:  98%|█████████▊| 11.8G/12.1G [01:26<00:02, 122MB/s]
# Downloading pytorch_model.bin:  98%|█████████▊| 11.9G/12.1G [01:26<00:01, 122MB/s]
# Downloading pytorch_model.bin:  98%|█████████▊| 11.9G/12.1G [01:26<00:01, 120MB/s]
# Downloading pytorch_model.bin:  98%|█████████▊| 11.9G/12.1G [01:26<00:01, 120MB/s]
# Downloading pytorch_model.bin:  99%|█████████▊| 11.9G/12.1G [01:27<00:01, 91.5MB/s]
# Downloading pytorch_model.bin:  99%|█████████▊| 12.0G/12.1G [01:27<00:01, 110MB/s]
# Downloading pytorch_model.bin:  99%|█████████▉| 12.0G/12.1G [01:27<00:01, 128MB/s]
# Downloading pytorch_model.bin:  99%|█████████▉| 12.0G/12.1G [01:27<00:00, 134MB/s]
# Downloading pytorch_model.bin:  99%|█████████▉| 12.0G/12.1G [01:27<00:00, 92.6MB/s]
# Downloading pytorch_model.bin:  99%|█████████▉| 12.0G/12.1G [01:27<00:00, 111MB/s]
# Downloading pytorch_model.bin: 100%|█████████▉| 12.1G/12.1G [01:27<00:00, 129MB/s]
# Downloading pytorch_model.bin: 100%|█████████▉| 12.1G/12.1G [01:28<00:00, 141MB/s]
# Downloading pytorch_model.bin: 100%|█████████▉| 12.1G/12.1G [01:28<00:00, 128MB/s]
# Downloading pytorch_model.bin: 100%|██████████| 12.1G/12.1G [01:28<00:00, 137MB/s]
# (ServeController pid=5772) WARNING 2023-10-08 21:39:47,948 controller 5772 deployment_state.py:1902 - Deployment default_PredictDeployment has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (ServeController pid=5772) WARNING 2023-10-08 21:40:18,009 controller 5772 deployment_state.py:1902 - Deployment default_PredictDeployment has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (ServeController pid=5772) WARNING 2023-10-08 21:40:48,044 controller 5772 deployment_state.py:1902 - Deployment default_PredictDeployment has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# (ServeController pid=5772) WARNING 2023-10-08 21:41:18,080 controller 5772 deployment_state.py:1902 - Deployment default_PredictDeployment has 1 replicas that have taken more than 30s to initialize. This may be caused by a slow __init__ or reconfigure method.
# Downloading (…)okenizer_config.json: 100%|██████████| 619/619 [00:00<00:00, 4.21MB/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 798k/798k [00:00<00:00, 12.0MB/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 6.39MB/s]
# Downloading (…)/main/tokenizer.json: 100%|██████████| 1.37M/1.37M [00:00<00:00, 47.3MB/s]
# Downloading (…)in/added_tokens.json: 100%|██████████| 4.04k/4.04k [00:00<00:00, 23.5MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 357/357 [00:00<00:00, 2.27MB/s]
# (ServeReplica:default_PredictDeployment pid=5871) Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2023-10-09 04:41:33,332	INFO router.py:853 -- Using PowerOfTwoChoicesReplicaScheduler.
# 2023-10-09 04:41:33,342	INFO router.py:329 -- Got updated replicas for deployment default_PredictDeployment: {'default_PredictDeployment#VwVcPr'}.
# RayServeSyncHandle(deployment='default_PredictDeployment')

# %%
import requests

prompt = (
    "Israel said it brought in special forces to try to wrest control of four Israeli sites "+
    "from Hamas fighters, including two kibbutzim that militants entered earlier in their attacks. "+
    "Footage released by Israeli police from one area showed forces kneeling in tall grass as they "+
    "exchanged fire with Hamas militants across an open field."
)

sample_input = {"text": prompt}

output = requests.post("http://example-cluster-kuberay-head-svc:8000/", json=[sample_input]).json()
print(output)
# Out:
# (ServeReplica:default_PredictDeployment pid=5871) The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# (ServeReplica:default_PredictDeployment pid=5871) Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'responses': 'Israel said it brought in special forces to try to wrest control of four Israeli sites from Hamas fighters, including two kibbutzim that militants entered earlier in their attacks. Footage released by Israeli police from one area showed forces kneeling in tall grass as they exchanged fire with Hamas militants across an open field.\n\nMeanwhile, the Israeli military said a "humanitarian" rocket had hit southern Israel earlier on Friday.\n\nIt said the projectile did not cause casualties or damage. Israel accused Gaza'}]
# (ServeReplica:default_PredictDeployment pid=5871) INFO 2023-10-08 21:43:45,355 default_PredictDeployment default_PredictDeployment#VwVcPr nwvZviHUvW / default replica.py:723 - __CALL__ OK 2679.9ms
