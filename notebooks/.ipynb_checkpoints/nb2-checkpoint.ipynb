# %% [markdown]
# ## Add required dependencies
# These will be moved to requirements.txt file

# %%
# !pip install "ray==2.6.1"
# !pip install "ray[serve]" requests diffusers transformers fastapi==0.96
# !pip install scikit-learn
# !pip install google-cloud-storage
# !pip install google-auth
# !pip install db-dtypes
# !pip install 'google-cloud-bigquery[pandas]'
# !pip install tensorflow
# !pip install langchain
# !pip install huggingface_hub
# Out:
# Collecting ray==2.6.1
#   Using cached ray-2.6.1-cp310-cp310-manylinux2014_x86_64.whl (56.9 MB)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (8.1.3)
# Collecting filelock (from ray==2.6.1)
#   Using cached filelock-3.12.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (4.17.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (1.0.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (23.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (4.21.12)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (6.0)
# Collecting aiosignal (from ray==2.6.1)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist (from ray==2.6.1)
#   Using cached frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (2.31.0)
# Requirement already satisfied: grpcio>=1.42.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (1.51.1)
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/lib/python3.10/site-packages (from ray==2.6.1) (1.24.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.6.1) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.6.1) (0.19.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.6.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.6.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.6.1) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.6.1) (2023.5.7)
# Installing collected packages: frozenlist, filelock, aiosignal, ray
# Successfully installed aiosignal-1.3.1 filelock-3.12.4 frozenlist-1.4.0 ray-2.6.1
# Requirement already satisfied: ray[serve] in /opt/conda/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.31.0)
# Collecting diffusers
#   Using cached diffusers-0.21.4-py3-none-any.whl (1.5 MB)
# Collecting transformers
#   Using cached transformers-4.34.0-py3-none-any.whl (7.7 MB)
# Collecting fastapi==0.96
#   Using cached fastapi-0.96.0-py3-none-any.whl (57 kB)
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 (from fastapi==0.96)
#   Using cached pydantic-1.10.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi==0.96)
#   Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (8.1.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (3.12.4)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (4.17.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.0.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (23.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (4.21.12)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (6.0)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.51.1)
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (1.24.3)
# Collecting virtualenv<20.21.1,>=20.0.24 (from ray[serve])
#   Using cached virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
# Collecting py-spy>=0.2.0 (from ray[serve])
#   Using cached py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# Requirement already satisfied: aiohttp>=3.7 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (3.7.4.post0)
# Collecting colorful (from ray[serve])
#   Using cached colorful-0.5.5-py2.py3-none-any.whl (201 kB)
# Collecting aiohttp-cors (from ray[serve])
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from ray[serve]) (0.17.0)
# Collecting aiorwlock (from ray[serve])
#   Using cached aiorwlock-1.3.0-py3-none-any.whl (10.0 kB)
# Collecting gpustat>=1.0.0 (from ray[serve])
#   Using cached gpustat-1.1.1-py3-none-any.whl
# Collecting smart-open (from ray[serve])
#   Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Collecting uvicorn (from ray[serve])
#   Using cached uvicorn-0.23.2-py3-none-any.whl (59 kB)
# Collecting opencensus (from ray[serve])
#   Using cached opencensus-0.11.3-py2.py3-none-any.whl (128 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2023.5.7)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from diffusers) (9.5.0)
# Collecting huggingface-hub>=0.13.2 (from diffusers)
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.10/site-packages (from diffusers) (6.6.0)
# Collecting regex!=2019.12.17 (from diffusers)
#   Using cached regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
# Collecting safetensors>=0.3.1 (from diffusers)
#   Using cached safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Using cached tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (23.1.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (4.0.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (6.0.4)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (1.9.2)
# Requirement already satisfied: typing-extensions>=3.6.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]) (4.6.2)
# Collecting nvidia-ml-py>=11.450.129 (from gpustat>=1.0.0->ray[serve])
#   Using cached nvidia_ml_py-12.535.108-py3-none-any.whl (36 kB)
# Requirement already satisfied: psutil>=5.6.0 in /opt/conda/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[serve]) (5.9.5)
# Collecting blessed>=1.17.1 (from gpustat>=1.0.0->ray[serve])
#   Using cached blessed-1.20.0-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (2023.5.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi==0.96) (3.6.2)
# Collecting distlib<1,>=0.3.6 (from virtualenv<20.21.1,>=20.0.24->ray[serve])
#   Using cached distlib-0.3.7-py2.py3-none-any.whl (468 kB)
# Requirement already satisfied: platformdirs<4,>=2.4 in /opt/conda/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[serve]) (3.5.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[serve]) (0.19.3)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[serve])
#   Using cached opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus->ray[serve])
#   Using cached google_api_core-2.12.0-py3-none-any.whl (121 kB)
# Collecting h11>=0.8 (from uvicorn->ray[serve])
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi==0.96) (1.3.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/conda/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[serve]) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[serve]) (1.16.0)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve])
#   Using cached googleapis_common_protos-1.60.0-py2.py3-none-any.whl (227 kB)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (2.17.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]) (0.4.8)
# Installing collected packages: py-spy, opencensus-context, nvidia-ml-py, distlib, colorful, virtualenv, smart-open, safetensors, regex, pydantic, h11, googleapis-common-protos, blessed, aiorwlock, uvicorn, starlette, huggingface-hub, gpustat, tokenizers, google-api-core, fastapi, diffusers, aiohttp-cors, transformers, opencensus
# Successfully installed aiohttp-cors-0.7.0 aiorwlock-1.3.0 blessed-1.20.0 colorful-0.5.5 diffusers-0.21.4 distlib-0.3.7 fastapi-0.96.0 google-api-core-2.12.0 googleapis-common-protos-1.60.0 gpustat-1.1.1 h11-0.14.0 huggingface-hub-0.17.3 nvidia-ml-py-12.535.108 opencensus-0.11.3 opencensus-context-0.1.3 py-spy-0.3.14 pydantic-1.10.13 regex-2023.10.3 safetensors-0.4.0 smart-open-6.4.0 starlette-0.27.0 tokenizers-0.14.1 transformers-4.34.0 uvicorn-0.23.2 virtualenv-20.21.0
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Collecting google-cloud-storage
#   Using cached google_cloud_storage-2.11.0-py2.py3-none-any.whl (118 kB)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.17.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.12.0)
# Collecting google-cloud-core<3.0dev,>=2.3.0 (from google-cloud-storage)
#   Using cached google_cloud_core-2.3.3-py2.py3-none-any.whl (29 kB)
# Collecting google-resumable-media>=2.6.0 (from google-cloud-storage)
#   Using cached google_resumable_media-2.6.0-py2.py3-none-any.whl (80 kB)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.31.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.60.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (4.21.12)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.2.7)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (4.9)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-resumable-media>=2.6.0->google-cloud-storage)
#   Using cached google_crc32c-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2023.5.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.4.8)
# Installing collected packages: google-crc32c, google-resumable-media, google-cloud-core, google-cloud-storage
# Successfully installed google-cloud-core-2.3.3 google-cloud-storage-2.11.0 google-crc32c-1.5.0 google-resumable-media-2.6.0
# Requirement already satisfied: google-auth in /opt/conda/lib/python3.10/site-packages (2.17.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth) (0.2.7)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from google-auth) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Collecting db-dtypes
#   Using cached db_dtypes-1.1.1-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from db-dtypes) (23.1)
# Requirement already satisfied: pandas>=0.24.2 in /opt/conda/lib/python3.10/site-packages (from db-dtypes) (2.0.2)
# Requirement already satisfied: pyarrow>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from db-dtypes) (10.0.1)
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.10/site-packages (from db-dtypes) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.2->db-dtypes) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.2->db-dtypes) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.2->db-dtypes) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->db-dtypes) (1.16.0)
# Installing collected packages: db-dtypes
# Successfully installed db-dtypes-1.1.1
# Collecting google-cloud-bigquery[pandas]
#   Using cached google_cloud_bigquery-3.12.0-py2.py3-none-any.whl (220 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.47.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (1.51.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (2.12.0)
# Collecting proto-plus<2.0.0dev,>=1.15.0 (from google-cloud-bigquery[pandas])
#   Using cached proto_plus-1.22.3-py3-none-any.whl (48 kB)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (2.6.0)
# Requirement already satisfied: packaging>=20.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (23.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (4.21.12)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (2.8.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (2.31.0)
# Requirement already satisfied: pandas>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (2.0.2)
# Requirement already satisfied: pyarrow>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (10.0.1)
# Requirement already satisfied: db-dtypes<2.0.0dev,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (1.1.1)
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.10/site-packages (from db-dtypes<2.0.0dev,>=0.3.0->google-cloud-bigquery[pandas]) (1.24.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery[pandas]) (1.60.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery[pandas]) (2.17.3)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery[pandas])
#   Using cached grpcio_status-1.59.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.10/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery[pandas]) (1.5.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.0->google-cloud-bigquery[pandas]) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.0->google-cloud-bigquery[pandas]) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery[pandas]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery[pandas]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery[pandas]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery[pandas]) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery[pandas]) (2023.5.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery[pandas]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery[pandas]) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery[pandas]) (4.9)
# Collecting grpcio<2.0dev,>=1.47.0 (from google-cloud-bigquery[pandas])
#   Using cached grpcio-1.59.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery[pandas]) (0.4.8)
# Installing collected packages: proto-plus, grpcio, grpcio-status, google-cloud-bigquery
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.51.1
#     Uninstalling grpcio-1.51.1:
#       Successfully uninstalled grpcio-1.51.1
# Successfully installed google-cloud-bigquery-3.12.0 grpcio-1.59.0 grpcio-status-1.59.0 proto-plus-1.22.3
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (2.11.1)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.21.12)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.6.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.3.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Collecting langchain
#   Downloading langchain-0.0.311-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.9 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.0.15)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Using cached aiohttp-3.8.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Requirement already satisfied: anyio<4.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (3.6.2)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Using cached dataclasses_json-0.6.1-py3-none-any.whl (27 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<0.1.0,>=0.0.43 (from langchain)
#   Using cached langsmith-0.0.43-py3-none-any.whl (40 kB)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.24.3)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.31.0)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<4.0->langchain) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<4.0->langchain) (1.3.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached marshmallow-3.20.1-py3-none-any.whl (49 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (4.6.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2023.5.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (23.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tenacity, mypy-extensions, marshmallow, jsonpatch, async-timeout, typing-inspect, langsmith, aiohttp, dataclasses-json, langchain
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.32
#     Uninstalling jsonpatch-1.32:
#       Successfully uninstalled jsonpatch-1.32
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 3.0.1
#     Uninstalling async-timeout-3.0.1:
#       Successfully uninstalled async-timeout-3.0.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.7.4.post0
#     Uninstalling aiohttp-3.7.4.post0:
#       Successfully uninstalled aiohttp-3.7.4.post0
# Successfully installed aiohttp-3.8.6 async-timeout-4.0.3 dataclasses-json-0.6.1 jsonpatch-1.33 langchain-0.0.311 langsmith-0.0.43 marshmallow-3.20.1 mypy-extensions-1.0.0 tenacity-8.2.3 typing-inspect-0.9.0
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (0.17.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (3.12.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2023.5.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.6.2)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (2023.5.7)

# %%
import ray
from ray import serve
from starlette.requests import Request
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ray
#       2 from ray import serve
#       3 from starlette.requests import Request
#
# ModuleNotFoundError: No module named 'ray'

# %%
ray.shutdown()
serve.shutdown()

# %%
# initialize ray
ray.init(
    address="ray://example-cluster-kuberay-head-svc:10001",
    runtime_env={
        "pip": [
            "IPython",
            "boto3==1.26",
            "botocore==1.29", 
            "datasets",
            "fastapi==0.96",
            "accelerate>=0.16.0",
            "transformers>=4.26.0",
            "numpy<1.24",  # remove when mlflow updates beyond 2.2
            "torch",
            "langchain",
            "huggingface_hub"
        ]
    }
)
# Out:
# ClientContext(dashboard_url='10.56.3.3:8265', python_version='3.10.8', ray_version='2.6.1', ray_commit='d68bf04883af2e430fc3a50fd544bb7c84aff2e9', protocol_version='2023-06-27', _num_clients=1, _context_to_restore=<ray.util.client._ClientContext object at 0x7aa093136740>)

# %%
HUGGINGFACEHUB_API_TOKEN = "..."

# %%
# https://python.langchain.com/docs/integrations/llms/huggingface_hub.html
# next: try using https://python.langchain.com/docs/integrations/llms/huggingface_pipelines

from langchain.llms import HuggingFaceHub
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from langchain.llms import OpenAI
from langchain.chains import SimpleSequentialChain
from langchain.chains import LLMChain
from langchain import PromptTemplate
import random
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = HUGGINGFACEHUB_API_TOKEN


text_model_name = "google/flan-t5-xxl"
# text_model_name = "chavinlo/gpt4-x-alpaca"
# model_name="gpt-3.5-turbo"

template1 = """Give me a fact about {topic}. """
template2 = "Translate to french: {fact}"

# create the prompt
prompt = PromptTemplate(
    input_variables=["topic"],
    template=template1,
)

# create the second prompt
second_prompt = PromptTemplate(
    input_variables=["fact"],
    template=template2,
)

def create_chain (llm):
    # create two chains 
    fact_chain = LLMChain(llm=llm, prompt=prompt)
    translate_chain = LLMChain(llm=llm, prompt=second_prompt)

    # combine the fact chain with the translate chain
    overall_chain = SimpleSequentialChain(chains=[fact_chain, translate_chain], verbose=True)
    return overall_chain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # https://python.langchain.com/docs/integrations/llms/huggingface_hub.html
# ----> 3 from langchain.llms import HuggingFaceHub
#       4 from langchain.prompts import PromptTemplate
#       5 from langchain.chains import LLMChain
#
# ModuleNotFoundError: No module named 'langchain'

# %%
llm = HuggingFaceHub(
    repo_id=text_model_name, model_kwargs={"temperature": 0.63 + random.uniform(-0.05, 0.05)}
)
overall_chain = create_chain(llm)

# Run the chain specifying only the input variable for the first chain.
overall_chain.run("football")
print (overall_chain)
# Out:
# > Entering new SimpleSequentialChain chain...
# a football consists of a ball
# chaque football consist de un balle,
#
# > Finished chain.
# verbose=True chains=[LLMChain(prompt=PromptTemplate(input_variables=['topic'], template='Give me a fact about {topic}. '), llm=HuggingFaceHub(client=InferenceAPI(api_url='https://api-inference.huggingface.co/pipeline/text2text-generation/google/flan-t5-xxl', task='text2text-generation', options={'wait_for_model': True, 'use_gpu': False}), repo_id='google/flan-t5-xxl', model_kwargs={'temperature': 0.6168526282915378})), LLMChain(prompt=PromptTemplate(input_variables=['fact'], template='Translate to french: {fact}'), llm=HuggingFaceHub(client=InferenceAPI(api_url='https://api-inference.huggingface.co/pipeline/text2text-generation/google/flan-t5-xxl', task='text2text-generation', options={'wait_for_model': True, 'use_gpu': False}), repo_id='google/flan-t5-xxl', model_kwargs={'temperature': 0.6168526282915378}))]

# %%
import pandas as pd

from ray import serve
from starlette.requests import Request
from langchain.llms import HuggingFaceHub
import os


@serve.deployment(ray_actor_options={"num_gpus": 1})
class DeployLLM:
    def __init__(self):
        os.environ["HUGGINGFACEHUB_API_TOKEN"] = HUGGINGFACEHUB_API_TOKEN
        print("Hello!")
        llm = HuggingFaceHub(
            repo_id=text_model_name, model_kwargs={"temperature": 0.5 + random.uniform(-0.1, 0.1)}
        )
        self.chain = create_chain(llm)

    def _run_chain(self, text: str):
        return self.chain.run(text)

    async def __call__(self, request: Request):
        # 1. Parse the request
        text = request.query_params["text"]
        # 2. Run the chain
        resp = self._run_chain(text)
        # 3. Return the response
        return resp

# %%
# Bind the model to deployment
deployment = DeployLLM.bind()

# %%
serve.run(deployment, host="0.0.0.0")
# Out:
# (ServeController pid=3210) INFO 2023-10-09 22:04:26,476 controller 3210 deployment_state.py:1308 - Deploying new version of deployment default_DeployLLM.
# 2023-10-10 05:04:26,584	INFO router.py:329 -- Got updated replicas for deployment default_DeployLLM: set().
# (ServeController pid=3210) INFO 2023-10-09 22:04:26,581 controller 3210 deployment_state.py:1459 - Stopping 1 replicas of deployment 'default_DeployLLM' with outdated versions.
# (ServeController pid=3210) INFO 2023-10-09 22:04:28,739 controller 3210 deployment_state.py:1571 - Adding 1 replica to deployment default_DeployLLM.
# (ServeReplica:default_DeployLLM pid=3776) /tmp/ray/session_2023-10-08_23-56-36_299089_8/runtime_resources/pip/d300173989dcc7d579bf827f50c5777b8bf02463/virtualenv/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:127: FutureWarning: '__init__' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '0.19.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
# (ServeReplica:default_DeployLLM pid=3776)   warnings.warn(warning_message, FutureWarning)
# (ServeReplica:default_DeployLLM pid=3776) Hello!
# 2023-10-10 05:04:32,361	INFO router.py:329 -- Got updated replicas for deployment default_DeployLLM: {'default_DeployLLM#oiWtgB'}.
# RayServeSyncHandle(deployment='default_DeployLLM')

# %%
import requests

query = "bunny"
response = requests.post(f'http://example-cluster-kuberay-head-svc:8000/?text={query}')
print(response.content.decode())
# Out:
# (ServeReplica:default_DeployLLM pid=3776)
# (ServeReplica:default_DeployLLM pid=3776)
# (ServeReplica:default_DeployLLM pid=3776) > Entering new SimpleSequentialChain chain...
# (ServeReplica:default_DeployLLM pid=3776) A bunny is a mammal
# Un chiffon est un mammifère
# (ServeReplica:default_DeployLLM pid=3776) Un chiffon est un mammifère
# (ServeReplica:default_DeployLLM pid=3776)
# (ServeReplica:default_DeployLLM pid=3776) > Finished chain.
# (ServeReplica:default_DeployLLM pid=3776) INFO 2023-10-09 22:11:25,305 default_DeployLLM default_DeployLLM#oiWtgB OauZSfuMAV / default replica.py:723 - __CALL__ OK 64.1ms

# %% [markdown]
# To delete deployment:
# ```
# serve.get_deployment("default_DeployLLM").delete()
# ```
#
# To list deployments:
# ```
# serve.list_deployments()
# ```
